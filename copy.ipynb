# %%
from kozel import GresniKozel

# %%
drevo = GresniKozel()

# %%
for i in range(0, 100, 10):
    drevo.insert(i)

# %%
drevo.draw_html()
# Out:
#         <svg width="550" height="530">
#
#             <line x1="25" y1="105"
#                   x2="75" y2="185"
#                   stroke="black" />
#
#             <line x1="125" y1="25"
#                   x2="25" y2="105"
#                   stroke="black" />
#
#             <line x1="125" y1="25"
#                   x2="275" y2="105"
#                   stroke="black" />
#
#             <line x1="175" y1="185"
#                   x2="225" y2="265"
#                   stroke="black" />
#
#             <line x1="275" y1="105"
#                   x2="175" y2="185"
#                   stroke="black" />
#
#             <line x1="275" y1="105"
#                   x2="325" y2="185"
#                   stroke="black" />
#
#             <line x1="325" y1="185"
#                   x2="375" y2="265"
#                   stroke="black" />
#
#             <line x1="375" y1="265"
#                   x2="425" y2="345"
#                   stroke="black" />
#
# ...

# %%
drevo.insert(42)
drevo.draw_html()
# Out:
#         <svg width="600" height="530">
#
#             <line x1="25" y1="105"
#                   x2="75" y2="185"
#                   stroke="black" />
#
#             <line x1="125" y1="25"
#                   x2="25" y2="105"
#                   stroke="black" />
#
#             <line x1="125" y1="25"
#                   x2="325" y2="105"
#                   stroke="black" />
#
#             <line x1="175" y1="185"
#                   x2="225" y2="265"
#                   stroke="black" />
#
#             <line x1="225" y1="265"
#                   x2="275" y2="345"
#                   stroke="black" />
#
#             <line x1="325" y1="105"
#                   x2="175" y2="185"
#                   stroke="black" />
#
#             <line x1="325" y1="105"
#                   x2="375" y2="185"
#                   stroke="black" />
#
#             <line x1="375" y1="185"
#                   x2="425" y2="265"
#                   stroke="black" />
#
# ...

# %%
drevo.remove(42)
drevo.draw_html()
# Out:
#         <svg width="550" height="530">
#
#             <line x1="25" y1="105"
#                   x2="75" y2="185"
#                   stroke="black" />
#
#             <line x1="125" y1="25"
#                   x2="25" y2="105"
#                   stroke="black" />
#
#             <line x1="125" y1="25"
#                   x2="275" y2="105"
#                   stroke="black" />
#
#             <line x1="175" y1="185"
#                   x2="225" y2="265"
#                   stroke="black" />
#
#             <line x1="275" y1="105"
#                   x2="175" y2="185"
#                   stroke="black" />
#
#             <line x1="275" y1="105"
#                   x2="325" y2="185"
#                   stroke="black" />
#
#             <line x1="325" y1="185"
#                   x2="375" y2="265"
#                   stroke="black" />
#
#             <line x1="375" y1="265"
#                   x2="425" y2="345"
#                   stroke="black" />
#
# ...

# %%
drevo.remove(20)
drevo.remove(10)
drevo.remove(0)
drevo.remove(50)
drevo.draw_html()
drevo.remove(30)
drevo.draw_html()
# Out:
#         <svg width="350" height="450">
#
#             <line x1="25" y1="25"
#                   x2="125" y2="105"
#                   stroke="black" />
#
#             <line x1="125" y1="105"
#                   x2="75" y2="185"
#                   stroke="black" />
#
#             <line x1="125" y1="105"
#                   x2="175" y2="185"
#                   stroke="black" />
#
#             <line x1="175" y1="185"
#                   x2="225" y2="265"
#                   stroke="black" />
#
#             <line x1="225" y1="265"
#                   x2="275" y2="345"
#                   stroke="black" />
#
#             <circle cx="25" cy="25" r="15"
#                     fill="#4CAF50" stroke="black"/>
#             <text x="25" y="30"
#                   font-size="12" text-anchor="middle"
#                   fill="white">30</text>
#
#             <circle cx="75" cy="185" r="15"
#                     fill="#4CAF50" stroke="black"/>
#             <text x="75" y="190"
# ...
