# %%
from kozel import GresniKozel
# Out:
# '1\n   2\n      3'

# %%
drevo = GresniKozel()

# %%
for i in range(0, 100, 10):
    drevo.insert(i)

# %%
drevo.draw_simple()
# Out:
# '0'

# %%
drevo.insert(42)
drevo.draw_simple()
# Out:
# '0\n   42'
