# %%
from DrevoGresnegaKozla import GresniKozel

# %%
drevo = GresniKozel()

# %%
for i in range(0, 100, 10):
    drevo.vstavi(i)

# %%
drevo.prikazi()
# Out:
# Kopica:
#             <style>
#             table, th, td {
#                 border: 1px solid white;
#             }
#             </style>
#             <table><tr></tr></table>
#         <svg width="836" height="386" viewBox="0 0 836 386" xmlns="http://www.w3.org/2000/svg">
#             <rect x="0" y="0" width="836" height="386" fill="white"/>
# ...

# %%
drevo.odstrani(20, True)
# Out:
# Kopica:
#             <style>
#             table, th, td {
#                 border: 1px solid white;
#             }
#             </style>
#             <table><tr><td>50</td></tr></table>
#         <svg width="836" height="386" viewBox="0 0 836 386" xmlns="http://www.w3.org/2000/svg">
#             <rect x="0" y="0" width="836" height="386" fill="white"/>
# ...

# %%
drevo.prikazi()
# Out:
# Kopica:
#             <style>
#             table, th, td {
#                 border: 1px solid white;
#             }
#             </style>
#             <table><tr></tr></table>
#         <svg width="756" height="386" viewBox="0 0 756 386" xmlns="http://www.w3.org/2000/svg">
#             <rect x="0" y="0" width="756" height="386" fill="white"/>
# ...
