# %%
from DrevoGresnegaKozla import GresniKozel

# %%
drevo = GresniKozel()

# %%
drevo.vstavi(50)

# %%
drevo.vstavi(30, True)
# Out:
# <h2>Iskanje starša<h2>
# Kopica:
#             <style>
#             table, th, td {
#                 border: 1px solid white;
#             }
#             </style>
#             <table><tr></tr></table>
#         <svg width="196" height="116" viewBox="0 0 196 116" xmlns="http://www.w3.org/2000/svg">
#             <rect x="0" y="0" width="196" height="116" fill="white"/>
#             <circle cx="58" cy="58" r="18" fill="#ffb3fe" stroke="#ce28b3" stroke-width="2"/><text x="58" y="63" text-anchor="middle" font-family="sans-serif" font-size="12" fill="#1a202c">50</text>
#         </svg>
# Kopica:
#             <style>
#             table, th, td {
#                 border: 1px solid white;
#             }
#             </style>
#             <table><tr><td>50</td></tr></table>
#         <svg width="196" height="206" viewBox="0 0 196 206" xmlns="http://www.w3.org/2000/svg">
#             <rect x="0" y="0" width="196" height="206" fill="white"/>
# ...

# %%
drevo.vstavi(60, True)
# Out:
# <h2>Iskanje starša<h2>
# Kopica:
#             <style>
#             table, th, td {
#                 border: 1px solid white;
#             }
#             </style>
#             <table><tr></tr></table>
#         <svg width="196" height="206" viewBox="0 0 196 206" xmlns="http://www.w3.org/2000/svg">
#             <rect x="0" y="0" width="196" height="206" fill="white"/>
#             <line x1="138" y1="58" x2="58" y2="148" stroke="#444" stroke-width="2"/><circle cx="138" cy="58" r="18" fill="#ffb3fe" stroke="#ce28b3" stroke-width="2"/><text x="138" y="63" text-anchor="middle" font-family="sans-serif" font-size="12" fill="#1a202c">50</text><circle cx="58" cy="148" r="18" fill="#e6f2ff" stroke="#2b6cb0" stroke-width="2"/><text x="58" y="153" text-anchor="middle" font-family="sans-serif" font-size="12" fill="#1a202c">30</text>
#         </svg>
# Kopica:
#             <style>
#             table, th, td {
#                 border: 1px solid white;
#             }
# ...

# %%
drevo.vstavi(40, True)
# Out:
# <h2>Iskanje starša<h2>
# Kopica:
#             <style>
#             table, th, td {
#                 border: 1px solid white;
#             }
#             </style>
#             <table><tr></tr></table>
#         <svg width="276" height="206" viewBox="0 0 276 206" xmlns="http://www.w3.org/2000/svg">
#             <rect x="0" y="0" width="276" height="206" fill="white"/>
# ...

# %%
drevo.vstavi(45, True)
# Out:
# <h2>Iskanje starša<h2>
# Kopica:
#             <style>
#             table, th, td {
#                 border: 1px solid white;
#             }
#             </style>
#             <table><tr></tr></table>
#         <svg width="356" height="296" viewBox="0 0 356 296" xmlns="http://www.w3.org/2000/svg">
#             <rect x="0" y="0" width="356" height="296" fill="white"/>
# ...
