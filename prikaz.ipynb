# %%
from DrevoGresnegaKozla import GresniKozel

# %%
drevo = GresniKozel()

# %%
for i in range(0, 100, 10):
    drevo.vstavi(i)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 2
#       1 for i in range(0, 100, 10):
# ----> 2     drevo.vstavi(i)
#
# File ~/source/Drevesa_gresnega_kozla/DrevoGresnegaKozla.py:53, in GresniKozel.vstavi(self, key, prikaz)
#      51 self.stack = []
#      52 self._vrini(key, prikaz)
# ---> 53 koza = self._gresni_kozel(prikaz)
#      54 koza = self._uravnovesi(koza)
#      55 if koza != None:
#
# File ~/source/Drevesa_gresnega_kozla/DrevoGresnegaKozla.py:206, in GresniKozel._gresni_kozel(self, prikazi)
#     204 if noda == None:
#     205     return
# --> 206 while self._je_uravnovesena_noda(noda, prikazi) == True and self.stack != []:
#     207     if noda == self.root:
#     208         return None
#
# File ~/source/Drevesa_gresnega_kozla/DrevoGresnegaKozla.py:181, in GresniKozel._je_uravnovesena_noda(self, node, prikazi)
#     178 if node is None:
# ...

# %%
drevo.vstavi(42, True)

# %%
drevo.prikazi()

# %%
drevo.odstrani(20, True)

# %%
drevo.prikazi()
