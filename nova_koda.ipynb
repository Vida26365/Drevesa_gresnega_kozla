# %%
class Node:
    def __init__(self, key):
        self.key = key
        self.left = None
        self.right = None
    def _html_node_row_(self):
        return f"<hd>{self.key}</hd><td>{self.left}</td><td>{self.right}</td>"

# %%
class Scapegoat:
    def __init__(self):
        self.root = None
        self.size = 0
        self.maxSize = 0
        
        self.stack = []

# %%
import html as _html
from IPython.display import HTML, display

def prikazi_steck(self):
    css = """
    <style>
    table, th, td {
        border: 1px solid white;
    }
    </style>
    """
    html = ""
    for noda in self.stack:
        html += f"<td>{noda.key}</td>"
    htmlk = f"{css}<table><tr>{html}</tr></table>"
    display(HTML(htmlk))
Scapegoat.prikazi_steck = prikazi_steck


def naslov(niz, i=1):
    html = f"<h{i}>{niz}<h{i}>"
    display(HTML(html))


def prikazi(self, node=None, scape=None):

    if self.root is None:
        display(HTML("<p>Tree is empty.</p>"))
        return

    coords = {}
    order = [0]
    max_depth = [0]

    def assign_positions(node, depth=0):
        if node is None:
            return
        assign_positions(node.left, depth + 1)
        coords[node] = (order[0], depth)
        order[0] += 1
        max_depth[0] = max(max_depth[0], depth)
        assign_positions(node.right, depth + 1)

    assign_positions(self.root)

    x_step = 80
    y_step = 90
    margin = 40
    radius = 18

    width = margin * 2 + max(1, order[0] - 1) * x_step + 2 * radius
    height = margin * 2 + max_depth[0] * y_step + 2 * radius

    def node_pixel(node):
        x_idx, depth = coords[node]
        x = margin + x_idx * x_step + radius
        y = margin + depth * y_step + radius
        return x, y

    parts = []

    def draw_edges(node):
        if node is None:
            return
        x1, y1 = node_pixel(node)
        if node.left is not None:
            x2, y2 = node_pixel(node.left)
            parts.append(f'<line x1="{x1}" y1="{y1}" x2="{x2}" y2="{y2}" stroke="#444" stroke-width="2"/>')
            draw_edges(node.left)
        if node.right is not None:
            x2, y2 = node_pixel(node.right)
            parts.append(f'<line x1="{x1}" y1="{y1}" x2="{x2}" y2="{y2}" stroke="#444" stroke-width="2"/>')
            draw_edges(node.right)

    def draw_nodes(current_node):
        if current_node is None:
            return
        x, y = node_pixel(current_node)
        label = _html.escape(str(current_node.key))
        fill_color = '#e6f2ff'
        stroke_color = '#2b6cb0'
        if node is not None and current_node is node:
            if scape == None:
                fill_color = "#ffb3fe"
                stroke_color = "#ce28b3"
            else:
                fill_color = '#ffd6d6' if scape else '#d9f7d9'
                stroke_color = '#c53030' if scape else '#2f855a'
        parts.append(f'<circle cx="{x}" cy="{y}" r="{radius}" fill="{fill_color}" stroke="{stroke_color}" stroke-width="2"/>')
        parts.append(f'<text x="{x}" y="{y + 5}" text-anchor="middle" font-family="sans-serif" font-size="12" fill="#1a202c">{label}</text>')
        draw_nodes(current_node.left)
        draw_nodes(current_node.right)

    draw_edges(self.root)
    draw_nodes(self.root)

    svg = f"""
    <svg width="{width}" height="{height}" viewBox="0 0 {width} {height}" xmlns="http://www.w3.org/2000/svg">
        <rect x="0" y="0" width="{width}" height="{height}" fill="white"/>
        {''.join(parts)}
    </svg>
    """
    display(HTML(svg))
    
Scapegoat.prikazi = prikazi

# %%
def vstavi(self, key, prikazi=False):
    noda = Node(key)

    noda.left = None
    noda.right = None
    
    if prikazi: naslov("Iskanje starša", 2)
    
    def _najdi_mesto_node_za_vstavit(root, noda):
        if prikazi == True:
            self.prikazi_steck()
            self.prikazi(root)
        if root == None:
            return 
        self.stack.append(root)
        if noda.key < root.key:
            if root.left == None:
                return root
            return _najdi_mesto_node_za_vstavit(root.left, noda)
        else:
            if root.right == None:
                return root
            return _najdi_mesto_node_za_vstavit(root.right, noda)
    stars = _najdi_mesto_node_za_vstavit(self.root, noda)
    
    if stars == None:
        self.root = noda
    
    else:
        if key < stars.key:
            stars.left = noda
        else:
            stars.right = noda
    
    self.size += 1
    if prikazi: self.prikazi(noda)
    
    # return noda
    
            
Scapegoat.vstavi = vstavi

# %%
def sizeOfSubtree(self, node):
    if node == None:
        return 0
    return 1 + self.sizeOfSubtree(node.left) + self.sizeOfSubtree(node.right)
Scapegoat.sizeOfSubtree = sizeOfSubtree


def isBalancedAtNode(self, node):
    if abs(self.sizeOfSubtree(node.left) - self.sizeOfSubtree(node.right)) <= 1:
        return True
    return False
Scapegoat.isBalancedAtNode = isBalancedAtNode

# %%
def findScapegoat(self,  prikazi=False):
    if prikazi: naslov("Najdi grešnega kozla", 2)
    if self.stack == []:
        return None
    node = self.stack.pop()
    while self.isBalancedAtNode(node) == True:
        if node == self.root:
            return None
        noda = self.stack.pop()
        if prikazi:
            self.prikazi_steck()
            self.prikazi(noda)
    return node
Scapegoat.findScapegoat = findScapegoat

# %%
import math

def rebalance(self, root):
    def flatten(node, nodes):
        if node == None:
            return
        flatten(node.left, nodes)
        nodes.append(node)
        flatten(node.right, nodes)

    def buildTreeFromSortedList(nodes, start, end):
        if start > end:
            return None
        mid = int(math.ceil(start + (end - start) / 2.0))
        node = Node(nodes[mid].key)
        node.left = buildTreeFromSortedList(nodes, start, mid-1)
        node.right = buildTreeFromSortedList(nodes, mid+1, end)
        return node

    nodes = []
    flatten(root, nodes)
    self.stack = []
    
    return buildTreeFromSortedList(nodes, 0, len(nodes)-1)

Scapegoat.rebalance = rebalance

# %%
def vstavi_plus(self, key, prikazi =  False):
    self.vstavi(key, prikazi)
    koza = self.findScapegoat(prikazi)

# %%
drevo = Scapegoat()
drevo.vstavi(50, True)
drevo.rebalance(drevo.findScapegoat())
# Out:
# <h2>Iskanje starša<h2>
#     <style>
#     table, th, td {
#         border: 1px solid white;
#     }
#     </style>
#     <table><tr></tr></table>
# <p>Tree is empty.</p>
#     <svg width="196" height="116" viewBox="0 0 196 116" xmlns="http://www.w3.org/2000/svg">
#         <rect x="0" y="0" width="196" height="116" fill="white"/>
#         <circle cx="58" cy="58" r="18" fill="#ffb3fe" stroke="#ce28b3" stroke-width="2"/><text x="58" y="63" text-anchor="middle" font-family="sans-serif" font-size="12" fill="#1a202c">50</text>
#     </svg>

# %%
drevo.vstavi(42, True)
drevo.rebalance(drevo.findScapegoat())
# Out:
# <h2>Iskanje starša<h2>
#     <style>
#     table, th, td {
#         border: 1px solid white;
#     }
#     </style>
#     <table><tr></tr></table>
#     <svg width="196" height="116" viewBox="0 0 196 116" xmlns="http://www.w3.org/2000/svg">
#         <rect x="0" y="0" width="196" height="116" fill="white"/>
#         <circle cx="58" cy="58" r="18" fill="#ffb3fe" stroke="#ce28b3" stroke-width="2"/><text x="58" y="63" text-anchor="middle" font-family="sans-serif" font-size="12" fill="#1a202c">50</text>
#     </svg>
#     <svg width="196" height="206" viewBox="0 0 196 206" xmlns="http://www.w3.org/2000/svg">
#         <rect x="0" y="0" width="196" height="206" fill="white"/>
#         <line x1="138" y1="58" x2="58" y2="148" stroke="#444" stroke-width="2"/><circle cx="138" cy="58" r="18" fill="#e6f2ff" stroke="#2b6cb0" stroke-width="2"/><text x="138" y="63" text-anchor="middle" font-family="sans-serif" font-size="12" fill="#1a202c">50</text><circle cx="58" cy="148" r="18" fill="#ffb3fe" stroke="#ce28b3" stroke-width="2"/><text x="58" y="153" text-anchor="middle" font-family="sans-serif" font-size="12" fill="#1a202c">42</text>
#     </svg>

# %%
drevo.vstavi(7, True)
drevo.rebalance(drevo.findScapegoat())
# Out:
# <h2>Iskanje starša<h2>
#     <style>
#     table, th, td {
#         border: 1px solid white;
#     }
#     </style>
#     <table><tr></tr></table>
#     <svg width="196" height="206" viewBox="0 0 196 206" xmlns="http://www.w3.org/2000/svg">
#         <rect x="0" y="0" width="196" height="206" fill="white"/>
#         <line x1="138" y1="58" x2="58" y2="148" stroke="#444" stroke-width="2"/><circle cx="138" cy="58" r="18" fill="#ffb3fe" stroke="#ce28b3" stroke-width="2"/><text x="138" y="63" text-anchor="middle" font-family="sans-serif" font-size="12" fill="#1a202c">50</text><circle cx="58" cy="148" r="18" fill="#e6f2ff" stroke="#2b6cb0" stroke-width="2"/><text x="58" y="153" text-anchor="middle" font-family="sans-serif" font-size="12" fill="#1a202c">42</text>
#     </svg>
#     <style>
#     table, th, td {
#         border: 1px solid white;
#     }
#     </style>
#     <table><tr><td>50</td></tr></table>
#     <svg width="196" height="206" viewBox="0 0 196 206" xmlns="http://www.w3.org/2000/svg">
#         <rect x="0" y="0" width="196" height="206" fill="white"/>
#         <line x1="138" y1="58" x2="58" y2="148" stroke="#444" stroke-width="2"/><circle cx="138" cy="58" r="18" fill="#e6f2ff" stroke="#2b6cb0" stroke-width="2"/><text x="138" y="63" text-anchor="middle" font-family="sans-serif" font-size="12" fill="#1a202c">50</text><circle cx="58" cy="148" r="18" fill="#ffb3fe" stroke="#ce28b3" stroke-width="2"/><text x="58" y="153" text-anchor="middle" font-family="sans-serif" font-size="12" fill="#1a202c">42</text>
#     </svg>
#     <svg width="276" height="296" viewBox="0 0 276 296" xmlns="http://www.w3.org/2000/svg">
#         <rect x="0" y="0" width="276" height="296" fill="white"/>
#         <line x1="218" y1="58" x2="138" y2="148" stroke="#444" stroke-width="2"/><line x1="138" y1="148" x2="58" y2="238" stroke="#444" stroke-width="2"/><circle cx="218" cy="58" r="18" fill="#e6f2ff" stroke="#2b6cb0" stroke-width="2"/><text x="218" y="63" text-anchor="middle" font-family="sans-serif" font-size="12" fill="#1a202c">50</text><circle cx="138" cy="148" r="18" fill="#e6f2ff" stroke="#2b6cb0" stroke-width="2"/><text x="138" y="153" text-anchor="middle" font-family="sans-serif" font-size="12" fill="#1a202c">42</text><circle cx="58" cy="238" r="18" fill="#ffb3fe" stroke="#ce28b3" stroke-width="2"/><text x="58" y="243" text-anchor="middle" font-family="sans-serif" font-size="12" fill="#1a202c">7</text>
#     </svg>
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[34], line 2
#       1 drevo.vstavi(7, True)
# ----> 2 drevo.rebalance(drevo.findScapegoat())
#
# Cell In[24], line 9, in findScapegoat(self, prikazi)
#       5     node = self.stack.pop()
#       6     while self.isBalancedAtNode(node) == True:
#       7         if node == self.root:
#       8             return None
# ----> 9         noda = self.stack.pop()
#      10         if prikazi:
#      11             self.prikazi_steck()
#      12             self.prikazi(noda)
#
# IndexError: pop from empty list
